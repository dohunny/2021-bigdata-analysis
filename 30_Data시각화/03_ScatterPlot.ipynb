# %% [markdown]
# # 3. Scatter Plot
# * 좌표상의 점들을 표시하여 두 변수간의 관계를 나타내는 그래프

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
x = np.random.rand(50) # [0, 1) == 0 이상 1 미만
y = np.random.rand(50)
plt.scatter(x, y)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(x, y)

x2 = np.random.rand(50)
y2 = np.random.rand(50)
plt.scatter(x2, y2)
plt.show()

# %%
# Marker 지정하기
plt.scatter(x, y, marker='*')
plt.show()

# %%
# Color 지정하기
plt.scatter(x, y, color='r')
plt.show()

# %%
# 점마다 다른 Color 지정하기
x = [1,2,3]
y = [1,2,3]
colors = ['r','g','b']
plt.scatter(x, y, c=colors)
plt.show()

# %%
# ColorMap(색상지도) 사용하기
# 데이터 값을 기반으로 색상 표현하기
plt.colormaps()
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y, c=x, cmap='Blues')
plt.colorbar()
plt.show()

# %%
# Marker Size 변경하기
size = np.random.randint(50) * 100
plt.scatter(x, y, c=x, cmap='Blues', s=size)
plt.show()

# %%
# 투명도 (alpha 값, 0~1)
plt.scatter(x, y, c=x, cmap='Blues', alpha=0.5)
plt.show()

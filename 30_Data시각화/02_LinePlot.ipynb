# %% [markdown]
# # 2. Line Plot (선 그래프)
# * 시간에 따른 변화의 추이를 시각화하는데 유용함
# * 예) 주가 변동, 기온 변화, 아파트 가격 변동

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2-1. 그래프 그리기

# %%
# (1,3), (8,10) 두 점을 연결하는 선 그래프 그리기
x = [1, 8]
y = [3, 10]
plt.plot(x, y)
plt.show()

# %%
# 두 점만 그리기 (marker: o - rings)
plt.plot(x, y, 'o')
plt.show()

# %%
# (1, 2) ~ (10, 20)
x = np.arange(1, 11) # 1~10
y = x * 2 # 2~20
plt.plot(x,y,'o')
plt.show()

# %%
# 점과 선 둘 다 그리기
plt.plot(x, y)
plt.plot(x, y, 'o')
# plt.plot(x, y, marker='o')
plt.show()

# %% [markdown]
# ## 2-2. Marker, Line, Color
# * Marker : https://matplotlib.org/stable/api/markers_api.html?highlight=marker
# * Line : https://matplotlib.org/3.0.3/gallery/lines_bars_and_markers/line_styles_reference.html
# * Color : https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
# Marker
plt.plot(x, y, marker='*', markersize=50) # markersize == ms
plt.show()

# %%
# Line Style
plt.plot(x, y, linestyle='-.') # linestyle == ls
plt.plot(y, x, linestyle='--')
plt.show()

# %%
# Color
plt.plot(x, y, color='r')
plt.plot(y, x, c='b', linewidth=5) # c == Color
plt.show()

# %%
# Format String
plt.plot(x, y, 'o:r')
plt.plot(y, x, '*--b')
plt.show()

# %%
# 그래프 분리하기 
plt.figure()    # 첫 번째 figure은 default
plt.plot(x, y, 'o:r')
plt.figure()    # 새로운 Canvas 생성
plt.plot(y, x, '*--b')
plt.show()

# %%
# 그래프 사이즈 변경하기 (단위 : inch) 
plt.figure(figsize=(5,5))
plt.plot(x, y)
plt.figure(figsize=(10,5))
plt.plot(y, x)
plt.show()

# %% [markdown]
# ## 2-3. Title, Label, Tick, Legend

# %%
# Title 설정
plt.title('Title', size=20)
plt.plot(x, y)
plt.show()

# %%
# Label 설정
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(x, y)
plt.show()

# %%
# Tick 설정
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.plot(x, y)
plt.show()

# %%
# Legend(범례) 설정
plt.plot(x, y)
plt.plot(y, x)
plt.legend(['(x, y)', '(y, x)'])
plt.show()

# %%
# legend(범례) 설정 2
plt.plot(x, y, label='(x, y)')
plt.plot(y, x, label='(y, x)')
plt.legend()
plt.show()

# %% [markdown]
# ## 2-4. Grid

# %%
# Grid
plt.plot(x, y)
plt.grid(axis='y')
plt.show()

# %%
# Grid 속성 변경하기
plt.plot(x, y, c='g')
plt.grid(ls=':', lw=2, c='r')
plt.show()

# %% [markdown]
# ## 2-5. Subplot
# * 하나의 figure에 여러개의 plot 그리기

# %%
# 1. subplot(row, column, index)
plt.subplot(1, 2, 1)
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.plot(y, x)
plt.show()

# %%
# (1, 2, 1) -> 121
plt.subplot(211)
plt.plot(x, y)
plt.title('(x,y)')
plt.subplot(212)
plt.plot(y, x)
plt.title('(y,x)')

plt.suptitle('Title', size=20)
plt.tight_layout()  # 자동 레이아웃 설정
plt.show()

# %%
# 2. add_subplot()
fig = plt.figure()
axes1 = fig.add_subplot(2, 1, 1)
axes2 = fig.add_subplot(2, 1, 2)

axes1.plot(x, y)
axes1.set_title('(x, y)')
axes2.plot(y, x)
axes2.set_title('(y, x)')
plt.show()

# %%
# 3. subplots()
fig,axes = plt.subplots(2, 1) # row, col

axes[0].plot(x, y)
axes[1].plot(y, x)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2-6. 그래프 용어 정리

# %%
from IPython.display import Image
Image('http://matplotlib.org/_images/anatomy.png')

# %% [markdown]
# # 2-7. 한글 출력하기

# %%
# 설치된 글꼴 찾기
from matplotlib import font_manager
from matplotlib import pyplot as plt
font_list = [f for f in font_manager.fontManager.ttflist]
print(len(font_list))   

font_list[:10]
# Out:
# 449
# [FontEntry(fname='/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', name='STIXGeneral', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', name='cmb10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')]

# %%
# 1. 전역으로 설정하기
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.size'] = 20
plt.plot(x, y)
plt.title('타이틀')
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53952 (\N{HANGUL SYLLABLE TEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
# 2. 특정 텍스트에만 설정하기 
fp = font_manager.FontProperties(fname=r'/System/Library/AssetsV2/com_apple_MobileAsset_Font6/ee9e9584cd1a5f676e03a9efcc80783bc7e12e2c.asset/AssetData/NanumGothic.ttc')
plt.plot(x, y)
plt.title('타이틀', fontproperties=fp)
# Out:
# Text(0.5, 1.0, '타이틀')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2288                 )
#    2289                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2290                     self.figure.draw(renderer)
#    2291
#    2292             if bbox_inches:
#
# /usr/local/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2801
#    2802             self.patch.draw(renderer)
# -> 2803             mimage._draw_list_compositing_images(
#    2804                 renderer, self, artists, self.suppressComposite)
#    2805
#
# /usr/local/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3044                 artists.remove(spine)
#    3045
# -> 3046         self._update_title_position(renderer)
#    3047
#    3048         if not self.axison:
#
# /usr/local/lib/python3.9/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2994                 _log.debug('top of Axes not in the figure, so title not moved')
#    2995                 return
# -> 2996             if title.get_window_extent(renderer).ymin < top:
#    2997                 _, y = self.transAxes.inverted().transform((0, top))
#    2998                 title.set_position((x, y))
#
# /usr/local/lib/python3.9/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     908
#     909         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 910             bbox, info, descent = self._get_layout(self._renderer)
#     911             x, y = self.get_unitless_position()
#     912             x, y = self.get_transform().transform((x, y))
#
# /usr/local/lib/python3.9/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     307
#     308         # Full vertical extent of font, including ascenders and descenders:
# --> 309         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     310             "lp", self._fontproperties,
#     311             ismath="TeX" if self.get_usetex() else False)
#
# /usr/local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     267
#     268         flags = get_hinting_flag()
# --> 269         font = self._get_agg_font(prop)
#     270         font.set_text(s, 0.0, flags=flags)
#     271         w, h = font.get_width_height()  # width and height of unrotated string
#
# /usr/local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in _get_agg_font(self, prop)
#     302         """
#     303         fname = findfont(prop)
# --> 304         font = get_font(fname)
#     305
#     306         font.clear()
#
# /usr/local/lib/python3.9/site-packages/matplotlib/font_manager.py in get_font(filename, hinting_factor)
#    1422         hinting_factor = rcParams['text.hinting_factor']
#    1423     # also key on the thread ID to prevent segfaults with multi-threading
# -> 1424     return _get_font(filename, hinting_factor,
#    1425                      _kerning_factor=rcParams['text.kerning_factor'],
#    1426                      thread_id=threading.get_ident())
#
# /usr/local/lib/python3.9/site-packages/matplotlib/font_manager.py in _get_font(filename, hinting_factor, _kerning_factor, thread_id)
#    1403 @lru_cache(64)
#    1404 def _get_font(filename, hinting_factor, *, _kerning_factor, thread_id):
# -> 1405     return ft2font.FT2Font(
#    1406         filename, hinting_factor, _kerning_factor=_kerning_factor)
#    1407
#
# FileNotFoundError: [Errno 2] No such file or directory: '/System/Library/AssetsV2/com_apple_MobileAsset_Font6/ee9e9584cd1a5f676e03a9efcc80783bc7e12e2c.asset/AssetData/NanumGothic.ttc'

# %%
# 3. 커널 실행 시 한글 설정하기
import matplotlib as mpl 
mpl.matplotlib_fname() # config files
# Out:
# '/usr/local/lib/python3.9/site-packages/matplotlib/mpl-data/matplotlibrc'

# %% [markdown]
# ## 2-8. 그래프 저장하기

# %%
plt.plot(x, y)
plt.savefig('graph.svg')

# %%
import matplotlib
import matplotlib.font_manager

[f.name for f in matplotlib.font_manager.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# ['Nanum Myeongjo', 'Nanum Brush Script', 'Nanum Gothic']

# %%
# 기본 설정 읽기
import matplotlib.pyplot as plt

# size, family
print (plt.rcParams['font.size'] ) 
print (plt.rcParams['font.family'] )
print (plt.rcParams['font.serif']) 
print (plt.rcParams['font.sans-serif']) 
print (plt.rcParams['font.monospace'])
# Out:
# 20.0
# ['NanumGothic']
# ['DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']
# ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif']
# ['DejaVu Sans Mono', 'Bitstream Vera Sans Mono', 'Computer Modern Typewriter', 'Andale Mono', 'Nimbus Mono L', 'Courier New', 'Courier', 'Fixed', 'Terminal', 'monospace']

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False

# %%
plt.plot(x, y)
plt.title('타이틀')
plt.show()

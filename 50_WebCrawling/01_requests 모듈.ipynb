# %% [markdown]
# # 1. requests 모듈
# * HTTP request/response를 처리하는 모듈
# * https://docs.python-requests.org/

# %% [markdown]
# ## requests 모듈 import

# %%
import requests

# %%
requests.__version__
# Out:
# '2.26.0'

# %%
#pip install reauest --upgrade

# %% [markdown]
# ### get 방식으로 요청하기

# %% [markdown]
# ### get 방식으로 요청하기
# * naver검색으로 get 방식 살펴보기
# * requests.get(url)
# * query parameters로 데이터 전달하기

# %%
ur1='http://httpbin.org/get'
params={
    'key1' : 'value1',
    'key2' : 'value2'
}
res=requests.get(ur1,params=params)
res
# Out:
# <Response [200]>

# %%
res.status_code
# Out:
# 200

# %%
# 응답 헤더
res.headers
# Out:
# {'Date': 'Mon, 06 Dec 2021 03:46:01 GMT', 'Content-Type': 'application/json', 'Content-Length': '379', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
# 요청 헤더
res.request.headers
# Out:
# {'User-Agent': 'python-requests/2.26.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
res.text
# Out:
# '{\n  "args": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.26.0", \n    "X-Amzn-Trace-Id": "Root=1-61ad8779-1cd6cb664912fa58069f8c81"\n  }, \n  "origin": "175.212.188.170", \n  "url": "http://httpbin.org/get?key1=value1&key2=value2"\n}\n'

# %%
res.json()
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.26.0',
#   'X-Amzn-Trace-Id': 'Root=1-61ad8779-1cd6cb664912fa58069f8c81'},
#  'origin': '175.212.188.170',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
type(res.json())
# Out:
# dict

# %%
res.json()['args']
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
res.json()['args']['key1']
# Out:
# 'value1'

# %% [markdown]
# ### post 방식으로 요청하기

# %% [markdown]
# * naver 로그인으로 post 방식 살펴보기
# * requests.post(url)
# * form data로 데이터 전달하기

# %%
url='http://httpbin.org/post'
data={
    'id' : 'test',
    'pwd' : 'testpwd'
}
res=requests.post(url,data=data)
res
# Out:
# <Response [200]>

# %%
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "id": "test", \n    "pwd": "testpwd"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "19", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.26.0", \n    "X-Amzn-Trace-Id": "Root=1-61ad877a-675009394a6f7c5332fa8b24"\n  }, \n  "json": null, \n  "origin": "175.212.188.170", \n  "url": "http://httpbin.org/post"\n}\n'

# %%
res.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'id': 'test', 'pwd': 'testpwd'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '19',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.26.0',
#   'X-Amzn-Trace-Id': 'Root=1-61ad877a-675009394a6f7c5332fa8b24'},
#  'json': None,
#  'origin': '175.212.188.170',
#  'url': 'http://httpbin.org/post'}

# %%
url='https://search.naver.com/search.naver'
params={
    'query' : '디미고'
}
res=requests.get(url,params=params)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="디미고 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'디미고\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'디미고\'의 네이버 통합검색 결과입니다."> <title>디미고 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_211202.css"> <link rel="stylesheet" type="text/css" hr
# ...

# %%
#네이버 기사 검색
url='https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=105&oid=366&aid=0000753766'

headers = {
    'user-agent':"Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Mobile Safari/537.36"
}
res=requests.get(url,headers=headers)
res
# Out:
# <Response [200]>

# %%
res.text[:1000]
# Out:
# '<!doctype html>\n<html lang="ko" data-useragent="Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Mobile Safari/537.36">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="“한정판, 응모하고 보자”…갤럭시Z폴드·플립3 톰브라운 에디션, 예약자 몰려 ‘대기 2시간’">\n\t\t<meta property="og:type" content="article">\n\t\t<meta property="og:url" content="https://n.news.naver.com/mnews/article/366/0000753766?sid&#x3D;105">\n\t\t<meta property="og:image" content="https://imgnews.pstatic.net/image/366/2021/08/12/0000753766_001_20210812104713034.gif">\n\t\t<meta property="og:description" content="삼성전자가 12일 오전 9시부터 진행 중인 ‘갤럭시 Z 폴드3 톰브라운 에디션’과 ‘갤럭시 Z 플립3 톰브라운 에디션’을 구매하기 위한 수요가 줄을 잇고 있다. 이날 오전 10시쯤 대기자는 9000명 이상으로, 응모">\n\t\t<meta property="og:article:author" content="조선비즈 | 네이버">\n\t\t<meta name="twitter:card
# ...

# %%
if res.status_code == requests.codes.ok: # 200
    print(res.text[:1000])
else:
    print('error')
# Out:
# <!doctype html>
# <html lang="ko" data-useragent="Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Mobile Safari/537.36">
# 	<head>
# 		<meta charset="utf-8">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
# 		<meta property="og:title" content="“한정판, 응모하고 보자”…갤럭시Z폴드·플립3 톰브라운 에디션, 예약자 몰려 ‘대기 2시간’">
# 		<meta property="og:type" content="article">
# 		<meta property="og:url" content="https://n.news.naver.com/mnews/article/366/0000753766?sid&#x3D;105">
# 		<meta property="og:image" content="https://imgnews.pstatic.net/image/366/2021/08/12/0000753766_001_20210812104713034.gif">
# 		<meta property="og:description" content="삼성전자가 12일 오전 9시부터 진행 중인 ‘갤럭시 Z 폴드3 톰브라운 에디션’과 ‘갤럭시 Z 플립3 톰브라운 에디션’을 구매하기 위한 수요가 줄을 잇고 있다. 이날 오전 10시쯤 대기자는 9000명 이상으로, 응모">
# 		<meta property="og:article:author" content="조선비즈 | 네이버">
# ...
